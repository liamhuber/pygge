# %%
from pygge.core import Graphic, Picture, Text
from pygge.shapes import Rectangle, Square, Hex, Ellipse, Circle
from PIL import Image
import numpy as np

# %%
rect = Rectangle((2000, 1000), color='white')
sq = Square(40, color='black')
ell = Ellipse((200, 400), color='green')
circ = Circle(90, color='blue')
hex_ = Hex((200, 160), color='red')

rect.add_graphic_to_center(sq.copy(), 'sq1', color='blue', layer=2)
rect.add_graphic_to_corner(sq.copy(), 'sq2', 'nw', buffer=290, color='green', layer=1, size=(100, 100))
# pict = Image.new('RGBA', (20, 20), color='black')
# rect.add_picture(
#     'pict', (20, 20), position=(0, 0), coordinate_frame='center', content=pict
# )
# rect.add_textbox_to_face(
#     'lorem', 'n', (200, 200), buffer=100, 
#     content='Here is my text. This is more text. So much text.',
#     font='../resources/fonts/Roboto-Regular.ttf'
# )
rect.image
# Out:
# <PIL.Image.Image image mode=RGBA size=2000x1000 at 0x11402E128>

# %%
sq.__dict__
# Out:
# {'_Positive___size': PILArray([40, 40]),
#  'color': 'black',
#  '_TwoDee__position': None,
#  '_IsOneOfThese__anchor': 'upper left',
#  '_IsOneOfThese__coordinate_frame': 'upper left',
#  'layer': 0,
#  'angle': 0,
#  'resample': 0,
#  'children': <pygge.core.Children at 0x1126fb128>,
#  '_image': None,
#  'parent': None,
#  '_name': 'parent'}
